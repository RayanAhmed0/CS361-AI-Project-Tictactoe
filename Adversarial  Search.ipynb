# %% [markdown]
# # **Introduction.**                       **<div style="direction:rtl">  مقدمة. </div>**
#
# <br></br>
#
#
#
#  <br>   </br>
#     This is the CS361 project of adversarial search algorithms.
#     In this project we will demonstrate how the Tic-tac-toe game algorithm performs and how can we implement the algorithm using min-max algorithm and alpha-beta pruning algorithm and then compare the results of both algorithms.
#      <br>   </br>
#      <div style="direction:rtl">هذا المشروع هو مشروع مادة عال361 ( الذكاء الاصطناعي) الذي يهتم بخوارزميات البحث العدائي.
#     في هذا المشروع سوف نستعرض كيفية عمل خوارزمية لعبة الاكس او وكيف يمكننا تطبيقها باستخدام خوارزمية مين-ماكس وخورازميةالفا-بيتا وبعد ذلك سوف نقارن النتائج بين الخوارزميتين</div>

# %% [markdown]
# ## 1. Game as search (initial state, state space, goal state)  <div style="direction:rtl"> الالعاب كخوارزمية بحث ( الحالة الابتدائية , فضاء الحالات , حالة الهدف). </div>
#     Initial state : In our project which is about algorithms in Tic-tac-toe game we have the 9 empty squares for each play
#     State space : Is 3^9 which is about 19683
#     GOAL state : Returns true of the game ends
#   <br>   </br>
#     <div style="direction:rtl"> الحالة الاولية : في مشروعنا هذا الذي يتمحور حول الخوارزميات في لعبة اكس او لدينا 9 مربعات فارغة لكل لعبة</div>
#   <br>   </br>
#      <div style="direction:rtl">فضاء الحالات : فضاء الحالات هو 3^9 ما يقارب 19683 حالة </div>
#   <br></br>
#     <div style="direction:rtl"> حالة الهدف : تعيد ترو في حالة نهاية اللعبة</div>

# %% [markdown]
# ## 2. Evaluation function <div style="direction:rtl">معادلة التقييم</div>
#     F(N) > 0 if the user is winning in position n
#     F(N) = 0 if position n is tied
#     F(N) < 0 if the opponent is winning in position n
# <br></br>
#    <div style="direction:rtl">F(N) > 0  اذا كان المستخدم فائزاً في الموضع (n)</div>
#  <br></br>
#     <div style="direction:rtl"> F(N) = 0  اذا كان الموضع متعادلاً بين الطرفين</div>
#    <br></br>
#   <div style="direction:rtl">   F(N) < 0  اذا كان الخصم فائزاً في الموضع (n)</div>

# %% [markdown]
# ## 3. Alpha-cut and Beta-cut  <div style="direction:rtl">قطع الفا وقطع بيتا</div>
#     In alpha-beta pruning:
#     The MAX cutoff rule: At a MAX node n , cut off search if a(n)>= B(n)
#     The MIN cutoff rule: At a MAX node n , cut off search if B(n)<= a(n)
# <br></br>
#  <div style="direction:rtl">في خوارزمية الفا بيتا : </div>
#   <div style="direction:rtl"> قاعدة القطع للماكس :  في الماكس للنقطة (إن) اقطع البحث اذا كان الفا(إن) اكبر من او يساوي بيتا(إن)</div>
#      <div style="direction:rtl"> قاعدة القطع للمين :  في الماكس للنقطة (إن) اقطع البحث اذا كان بيتا(إن) اصغر من او يساوي الفا(إن)</div>

# %% [markdown]
# ## 4. Performance measure  <div style="direction:rtl">معيار الاداء</div>
#     For min-max : Performance will depend on
#         1- The quality of the evaluation function(expert knowledge)
#         2- depth of search (computing power and search algorithm)
#     For alpha-beta :
#         1- Same as min-max but faster
# <br></br>
#      <div style="direction:rtl">لخوازمية المين-ماكس  الاداء يعتمد على :</div>
#      <br></br>  <div style="direction:rtl">1-جودة معادلة التقييم</div>
#      <br></br>  <div style="direction:rtl">2-عمق البحث (قدرة المعالجة و خوارزمية البحث)</div>
#      <br></br>
#      <div style="direction:rtl">لخوازمية الفا-بيتا  الاداء يعتمد على :</div>
#      <br></br>  <div style="direction:rtl">1- انها اسرع بحثاً من خوارزمية مين ماكس</div>

# %% [markdown]
# ## 5. Example for each concept  <div style="direction:rtl">مثال لكل فكرة</div>

# %% [markdown]
# Alpha-beta Example  <div style="direction:rtl">مثال خوارزمية الفا بيتا</div>
#
#  ![](alpha.png)
#
# Min-max Example <div style="direction:rtl">مثال خوارزمية مين ماكس</div>
#
#  ![](minimax.png)

# %% [markdown]
# ## 6. Any knowledge you learnt about games <div style="direction:rtl">اي معلومات تعلمناها عن الالعاب</div>

# %% [markdown]
#     Games are not a simple thing to understand ,
#     They involve much complex algorithms .
#
#     Every game is actually an algorithm or a bunch of algorithms .
#
#     AI games are not smart ! , they just some algorithms that work together behind the scenes.
#
# <br></br>
#  <div style="direction:rtl">الالعاب ليست سهلة الفهم </div>
#  <br></br>
#  <div style="direction:rtl">الالعاب تتضمن خوارزميات معقدة</div>
#  <br></br>
#  <div style="direction:rtl">كل لعبة هي في الحقيقة خوارزمية او مجموعة خوارزميات</div>
#  <br></br>
#  <div style="direction:rtl">العاب الذكاء الاصطناعي ليست بذلك الذكاء ! , هم مجرد خوارزميات تعمل معاً خلف الكواليس</div>

# %% [markdown]
# - ## **An example game X-O.**  <div style="direction:rtl">مثال للعبة اكس او</div>
#
# Explains the problem and its formulation
# <br></br>
#  <div style="direction:rtl">شرح المشكلة </div>

# %% [markdown]
#     Tic-tac-toe is a game consists of 2 players X and O take alternative turn on 3x3 board to form a line of 3Xs or 3Os
# <br></br>
#  <div style="direction:rtl">لعبة الاكس او تحتوي على لاعبين احدهما اكس والاخر او ويتبادلون الادوار على لوحة حجمها 3 ضرب 3 ليكونوا خطاً مستقيماً من 3 اكس او 3 او</div>

# %% [markdown]
# - ## **The algorithms**  <div style="direction:rtl">الخوارزميات</div>

# %% [markdown]
# - ### **Explanation**  <div style="direction:rtl">شرح الخوارزميات</div>
# <br></br>
#
# ### Min-max:<div style="direction:rtl">مين ماكس</div> ![](minmaxexpl.png)
# <br></br>
# ### Alpha-beta:<div style="direction:rtl">الفا بيتا</div> ![](alphaexpl.png)

# %% [markdown]
# - ### **Implementation using Alpha-beta**
# ### <div style="direction:rtl">تطبيق اللعبة باستخدام الفا بيتا</div>

# %%
from random import choice
from math import inf
import time

XPLAYER = +1
OPLAYER = -1
EMPTY = 0
global counter


board = [[EMPTY, EMPTY, EMPTY],
         [EMPTY, EMPTY, EMPTY],
         [EMPTY, EMPTY, EMPTY]]


def printBoard(brd):
    chars = {XPLAYER: 'X', OPLAYER: 'O', EMPTY: ' '}
    for x in brd:
        for y in x:
            ch = chars[y]
            print(f'| {ch} |', end='')
        print('\n' + '---------------')
    print('===============')


def clearBoard(brd):
    for x, row in enumerate(brd):
        for y, col in enumerate(row):
            brd[x][y] = EMPTY


def winningPlayer(brd, player):
    winningStates = [[brd[0][0], brd[0][1], brd[0][2]],
                     [brd[1][0], brd[1][1], brd[1][2]],
                     [brd[2][0], brd[2][1], brd[2][2]],
                     [brd[0][0], brd[1][0], brd[2][0]],
                     [brd[0][1], brd[1][1], brd[2][1]],
                     [brd[0][2], brd[1][2], brd[2][2]],
                     [brd[0][0], brd[1][1], brd[2][2]],
                     [brd[0][2], brd[1][1], brd[2][0]]]

    if [player, player, player] in winningStates:
        return True

    return False


def MiniMaxAB(brd, depth, alpha, beta, player):

    row = -1
    col = -1
    if depth == 0 or gameWon(brd):
        return [row, col, getScore(brd)]

    else:
        for cell in emptyCells(brd):
            setMove(brd, cell[0], cell[1], player)
            score = MiniMaxAB(brd, depth - 1, alpha, beta, -player)

            if player == XPLAYER:
                # X is always the max player
                if score[2] > alpha:
                    alpha = score[2]
                    row = cell[0]
                    col = cell[1]

            else:
                if score[2] < beta:
                    beta = score[2]
                    row = cell[0]
                    col = cell[1]

            setMove(brd, cell[0], cell[1], EMPTY)

            if alpha >= beta:
                break

        if player == XPLAYER:

            return [row, col, alpha]

        else:

            return [row, col, beta]


def gameWon(brd):
    return winningPlayer(brd, XPLAYER) or winningPlayer(brd, OPLAYER)


def printResult(brd):

    if winningPlayer(brd, XPLAYER):
        print('X has won! ' '\n')

    elif winningPlayer(brd, OPLAYER):
        print('O\'s have won! ' '\n')
    else:
        print('Draw' '\n')


def emptyCells(brd):
    emptyC = []
    for x, row in enumerate(brd):
        for y, col in enumerate(row):
            if brd[x][y] == EMPTY:
                emptyC.append([x, y])

    return emptyC


def boardFull(brd):
    if len(emptyCells(brd)) == 0:
        return True
    return False


def setMove(brd, x, y, player):
    brd[x][y] = player


def playerMove(brd):
    e = True
    moves = {1: [0, 0], 2: [0, 1], 3: [0, 2],
             4: [1, 0], 5: [1, 1], 6: [1, 2],
             7: [2, 0], 8: [2, 1], 9: [2, 2]}
    while e:
        try:
            move = int(input('Pick a position(1-9)'))
            if move < 1 or move > 9:
                print('Invalid location! ')
            elif not (moves[move] in emptyCells(brd)):
                print('Location filled')
            else:
                setMove(brd, moves[move][0], moves[move][1], XPLAYER)
                printBoard(brd)
                e = False
        except (KeyError, ValueError):
            print('Please pick a number!')


def getScore(brd):
    if winningPlayer(brd, XPLAYER):
        return 10

    elif winningPlayer(brd, OPLAYER):
        return -10

    else:
        return 0


def AIMove(brd):
    if len(emptyCells(brd)) == 9:
        x = choice([0, 1, 2])
        y = choice([0, 1, 2])
        setMove(brd, x, y, OPLAYER)
        printBoard(brd)

    else:
        result = MiniMaxAB(brd, len(emptyCells(brd)), -inf, inf, OPLAYER)
        setMove(brd, result[0], result[1], OPLAYER)
        printBoard(brd)


def AI2Move(brd):
    if len(emptyCells(brd)) == 9:
        x = choice([0, 1, 2])
        y = choice([0, 1, 2])
        setMove(brd, x, y, XPLAYER)
        printBoard(brd)

    else:
        result = MiniMaxAB(brd, len(emptyCells(brd)), -inf, inf, XPLAYER)
        setMove(brd, result[0], result[1], XPLAYER)
        printBoard(brd)


def AIvsAI():
    counter = 0
    currentPlayer = XPLAYER
    count = 0
    for x in range(1000): #1000 is the times of trying to play for AI also it's the depth
        counter += 1
        clearBoard(board)

        while not (boardFull(board) or gameWon(board)):
            makeMove(board, currentPlayer, 2)
            currentPlayer *= -1

        printResult(board)
        if gameWon(board):
            count += 1

    print('Number of AI vs AI wins =', count)
    print("Depth of the tree", counter)


def makeMove(brd, player, mode):
    if mode == 1:
        if player == XPLAYER:
            playerMove(brd)

        else:
            AIMove(brd)
    else:
        if player == XPLAYER:
            AIMove(brd)
        else:
            AI2Move(brd)


def playerVSai():
    counter = 0
    while True:

        try:
            order = int(input('Would you like to go first or second? (1/2)? '))
            if not (order == 1 or order == 2):
                print('Please pick 1 or 2')
            else:
                break
        except (KeyError, ValueError):
            print('Enter a number')

    clearBoard(board)
    if order == 2:
        currentPlayer = OPLAYER
    else:
        currentPlayer = XPLAYER

    while not (boardFull(board) or gameWon(board)):
        makeMove(board, currentPlayer, 1)
        currentPlayer *= -1
        counter += 1

    printResult(board)
    print("Depth of the tree", counter)


def main():

    while True:

        user = input('Play?(Y/N) ')
        if user.lower() == 'y':
            start = time.time()
            time.sleep(0.1)
            t = input('AI vs AI or Player vs AI(1/2)')
            if int(t) == 1:
                AIvsAI()
                end = time.time()
                total_time = end - start
                print("\n Execution Time is :" + str(total_time))
                print("\n The size of the Tic-tac-toe tree is : 9! = 362880")
            else:
                playerVSai()
                end = time.time()
                total_time = end - start
                print("\n Execution Time is :" + str(total_time))
                print("The size of the Tic-tac-toe tree is : 9! = 362880")

        else:

            print('Bye!')
            exit()


if __name__ == '__main__':
    main()

# %% [markdown]
# - ### **Implementation using Min-max**
# ### <div style="direction:rtl">تطبيق اللعبة باستخدام مين ماكس </div>

# %%
import time

def printBoard(board):
    print(board[1] + '|' + board[2] + '|' + board[3])
    print('-----')
    print(board[4] + '|' + board[5] + '|' + board[6])
    print('-----')
    print(board[7] + '|' + board[8] + '|' + board[9])
    print("==============")
    


def spaceIsFree(position):
    if board[position] == ' ':
        return True
    else:
        return False

 
def insertLetter(letter, position):
    if spaceIsFree(position):
        board[position] = letter
        # next state 
        printBoard(board) 
        if (checkBoard()):
            print("It's a tie!")
            exit()
        if checkForWin():
            if letter == 'X':
                print("computer wins!")
                exit()
            else:
                print("player wins!")
                exit()

        return


    else:
        print("Can't insert there!")
        position = int(input("Please enter new position:  "))
        insertLetter(letter, position)
        return


def checkForWin():
    if (board[1] == board[2] and board[1] == board[3] and board[1] != ' '):
        return True
    elif (board[4] == board[5] and board[4] == board[6] and board[4] != ' '):
        return True
    elif (board[7] == board[8] and board[7] == board[9] and board[7] != ' '):
        return True
    elif (board[1] == board[4] and board[1] == board[7] and board[1] != ' '):
        return True
    elif (board[2] == board[5] and board[2] == board[8] and board[2] != ' '):
        return True
    elif (board[3] == board[6] and board[3] == board[9] and board[3] != ' '):
        return True
    elif (board[1] == board[5] and board[1] == board[9] and board[1] != ' '):
        return True
    elif (board[7] == board[5] and board[7] == board[3] and board[7] != ' '):
        return True
    else:
        return False


def checkBoard():
    for key in board.keys():
        if (board[key] == ' '):
            return False
    return True


def playerMove():
    position = int(input("Enter the position for 'O':  "))
    insertLetter(player, position)
    return


def compMove():
    bestScore = -800 
    bestMove = 0
    for key in board.keys():
        if (board[key] == ' '):
            board[key] = computer
            score = minimax(board, False)
            board[key] = ' '
            if (score > bestScore):
                bestScore = score
                bestMove = key

    insertLetter(computer, bestMove)
    return


def minimax(board, isMaximizing):
    if (checkWhichWon(computer)):
        return 1
    elif (checkWhichWon(player)):
        return -1
    elif (checkBoard()): 
        return 0

    if (isMaximizing):
        bestScore = -800
        for key in board.keys():
            if (board[key] == ' '):
                board[key] = computer
                score = minimax(board,False)
                board[key] = ' '
                if (score > bestScore):
                    bestScore = score
        return bestScore

    else:
        bestScore = 800
        for key in board.keys():
            if (board[key] == ' '):
                board[key] = player
                score = minimax(board, True)
                board[key] = ' '
                if (score < bestScore):
                    bestScore = score
        return bestScore

       

def checkWhichWon(letter):
    if board[1] == board[2] and board[1] == board[3] and board[1] == letter:
        return True
    elif (board[4] == board[5] and board[4] == board[6] and board[4] == letter):
        return True
    elif (board[7] == board[8] and board[7] == board[9] and board[7] == letter):
        return True
    elif (board[1] == board[4] and board[1] == board[7] and board[1] == letter):
        return True
    elif (board[2] == board[5] and board[2] == board[8] and board[2] == letter):
        return True
    elif (board[3] == board[6] and board[3] == board[9] and board[3] == letter):
        return True
    elif (board[1] == board[5] and board[1] == board[9] and board[1] == letter):
        return True
    elif (board[7] == board[5] and board[7] == board[3] and board[7] == letter):
        return True
    else:
        return False


board = {1: ' ', 2: ' ', 3: ' ',
         4: ' ', 5: ' ', 6: ' ',
         7: ' ', 8: ' ', 9: ' '}

printBoard(board)
print("Computer goes first! Good luck.")
print("Positions are as follow:")
# print("1, 2, 3 ")
# print("4, 5, 6 ")
# print("7, 8, 9 ")
print("\n")
player = 'O'
computer = 'X'



while not checkForWin():
    # x
    compMove()
    # o
    playerMove()

# %% [markdown]
# - ### **Testing the two algorithms on several samples of X_O games.<br><br>**  **&** **<br><br>Compare and Interpret your experimental results.**
# ### <div style="direction:rtl">تجربة الخوارزميتين على عدة عينات من اللعب ومقارنة النتائج</div>

# %% [markdown]
# ![](ssss.png)

# %% [markdown]
#     As you can see above in the chart , The number of wins is 0 as we mostly get beaten by the Algorithm or tied , execution time is written above and below every win/lose/tie , size of the tree and depth of the tree is printed in the code along with the execution time of the algorithm .
# <br></br>
#  <div style="direction:rtl">كما ترون في الاعلى في الجدول , عدد الفوز هو 0 , غالباً ما نخسر من الخصم الذي هو الخوارزمية او نتعادل ,وقت التشغيل مكتوب في الجدول تحت كل فوز/خسارة/تعادل , حجم الشجرة وعمقها مطبوع مع تشغيل الكود ملحقاً بوقت تشغيل الخوارزمية</div>

# %% [markdown]
# - ## **References and resources**
#  ## <div style="direction:rtl">المراجع والمصادر</div>
#     1- Artificial Intelligence (CS 361) Chapter Games: Adversarial Search IMAMU
#
#     2- https://raphsilva.github.io/utilities/minimax_simulator/#
#
#     3- https://www.researchgate.net/figure/Game-tree-for-Tic-Tac-Toe-game-using-MiniMax-algorithm_fig1_262672371
#
#     4- https://ai.stackexchange.com/questions/4583/can-i-prune-the-tree-if-alpha-beta-pruning-finds-10-to-the-left-of-the-root-node
#
#     5- https://github.com/ckallum/Unbeatable-TicTacToe
#
#     6- https://github.com/Cledersonbc/ai-tic-tac-toe-minimax
#
#     7- https://slidesgo.com/theme/artificial-intelligence-in-chemistry-services-company-profile#search-AI&position-10&results-10&rs=search
